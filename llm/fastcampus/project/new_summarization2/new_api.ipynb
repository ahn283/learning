# %%
from new_api import get_urls, parse_text
from tqdm.notebook import tqdm

total_list = []
keywords = ['inflation', 'real estate']

# %%
for keyword in tqdm(keywords):
    df = get_urls(keyword, start_date='2024-03-25', end_date='2024-03-27')
    result_list = parse_text(df)
    total_list.extend(result_list)
    
for line in total_list:
    print(line)
    print()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
unique_list = []
unique_titles = []
for line in tqdm(total_list):
    if line['title'] not in unique_titles:
        print(line['title'])
        print('unique')
        unique_list.append(line)
    else:
        continue
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# Opinion | This Is the Best Way for Joe Biden to Talk About the Economy
# unique
# Conversations and insights about the moment . - The New York Times
# unique
# Conversations and insights about the moment . - The New York Times
# unique
# Conversations and insights about the moment . - The New York Times
# unique
# Conversations and insights about the moment . - The New York Times
# unique
# Conversations and insights about the moment . - The New York Times
# unique
# Conversations and insights about the moment . - The New York Times
# unique
# Conversations and insights about the moment . - The New York Times
# unique
# Conversations and insights about the moment . - The New York Times
# unique
# Conversations and insights about the moment . - The New York Times
# unique
# Conversations and insights about the moment . - The New York Times
# unique
# Conversations and insights about the moment . - The New York Times
# unique
# ...

# %%
import pandas as pd
pd.DataFrame(unique_list)['title']
# Out:
# 0     Opinion | This Is the Best Way for Joe Biden t...
# 1     Conversations and insights about the moment . ...
# 2     Conversations and insights about the moment . ...
# 3     Conversations and insights about the moment . ...
# 4     Conversations and insights about the moment . ...
# 5     Conversations and insights about the moment . ...
# 6     Conversations and insights about the moment . ...
# 7     Conversations and insights about the moment . ...
# 8     Conversations and insights about the moment . ...
# 9     Conversations and insights about the moment . ...
# 10    Conversations and insights about the moment . ...
# 11    Conversations and insights about the moment . ...
# 12    Conversations and insights about the moment . ...
# 13    Conversations and insights about the moment . ...
# 14    Conversations and insights about the moment . ...
# Name: title, dtype: object
