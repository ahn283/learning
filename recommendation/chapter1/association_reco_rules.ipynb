# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# load the data from the UCI Machine Learning Repository
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx"
online_retail_data = pd.read_excel(url)

# %%
online_retail_data.head(10)
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
# 5    536365     22752  ...    17850.0  United Kingdom
# 6    536365     21730  ...    17850.0  United Kingdom
# 7    536366     22633  ...    17850.0  United Kingdom
# 8    536366     22632  ...    17850.0  United Kingdom
# 9    536367     84879  ...    13047.0  United Kingdom
#
# [10 rows x 8 columns]

# %%
# Data prerprocessing
online_retail_data['Decription'] = online_retail_data['Description'].str.strip()
online_retail_data = online_retail_data.dropna(axis=0, subset=['InvoiceNo'])
online_retail_data['InvoiceNo'] = online_retail_data['InvoiceNo'].astype('str')
online_retail_data = online_retail_data[~online_retail_data['InvoiceNo'].str.contains('C')]     # 취소

# %%
online_retail_data.sample(20)
# Out:
#        InvoiceNo StockCode  ...         Country                           Decription
# 321454    565150     22488  ...  United Kingdom   NATURAL SLATE RECTANGLE CHALKBOARD
# 7841      537057     22383  ...  United Kingdom               LUNCH BAG SUKI  DESIGN
# 59821     541410     21672  ...  United Kingdom   WHITE SPOT RED CERAMIC DRAWER KNOB
# 145188    548870     21889  ...  United Kingdom               WOODEN BOX OF DOMINOES
# 354094    567859     21833  ...  United Kingdom                 CAMOUFLAGE LED TORCH
# 511872    579508     23407  ...  United Kingdom       SET OF 2 TRAYS HOME SWEET HOME
# 188650    553052     23170  ...  United Kingdom              REGENCY TEA PLATE ROSES
# 242779    558371     21673  ...  United Kingdom  WHITE SPOT BLUE CERAMIC DRAWER KNOB
# 520808    580304     22940  ...  United Kingdom            FELTCRAFT CHRISTMAS FAIRY
# 453342    575477    85099B  ...  United Kingdom              JUMBO BAG RED RETROSPOT
# 105802    545288    85099B  ...  United Kingdom              JUMBO BAG RED RETROSPOT
# 56781     541115     22366  ...           Italy                      DOORMAT AIRMAIL
# 120526    546658     21670  ...  United Kingdom        BLUE SPOT CERAMIC DRAWER KNOB
# 116579    546253     22720  ...  United Kingdom     SET OF 3 CAKE TINS PANTRY DESIGN
# 52170     540691     22120  ...  United Kingdom        WELCOME  WOODEN BLOCK LETTERS
# 105892    545295     22626  ...         Germany                 BLACK KITCHEN SCALES
# 66022     541711     21933  ...     Netherlands      PINK VINTAGE PAISLEY PICNIC BAG
# 130847    547513    46000P  ...  United Kingdom       POLYESTER FILLER PAD 65CMx65CM
# 368235    568949    90214Z  ...  United Kingdom            LETTER "Z" BLING KEY RING
# 458633    575846     23318  ...  United Kingdom       BOX OF 6 MINI VINTAGE CRACKERS
#
# [20 rows x 9 columns]

# %%
# convert transation data into a basket format
basket = (online_retail_data[online_retail_data['Country'] == 'United Kingdom']
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))
basket
# Out:
# Description  20713  ...  wrongly sold sets
# InvoiceNo           ...
# 536365         0.0  ...                0.0
# 536366         0.0  ...                0.0
# 536367         0.0  ...                0.0
# 536368         0.0  ...                0.0
# 536369         0.0  ...                0.0
# ...            ...  ...                ...
# 581585         0.0  ...                0.0
# 581586         0.0  ...                0.0
# A563185        0.0  ...                0.0
# A563186        0.0  ...                0.0
# A563187        0.0  ...                0.0
#
# [18668 rows x 4188 columns]

# %%
# convert the quantities into O/I (O: not in the basket, I : in the basket)
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
    
basket_set = basket.applymap(encode_units)

# use the Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(basket_set, min_support=0.03, use_colnames=True)

frequent_itemsets
# Out:
# C:\Users\ahn28\AppData\Local\Temp\ipykernel_21012\1610977869.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket_set = basket.applymap(encode_units)
#       support                                           itemsets
# 0    0.045800                           (6 RIBBONS RUSTIC CHARM)
# 1    0.031123                  (60 CAKE CASES VINTAGE CHRISTMAS)
# 2    0.040336                      (60 TEATIME FAIRY CAKE CASES)
# 3    0.046925                       (ALARM CLOCK BAKELIKE GREEN)
# 4    0.035140                        (ALARM CLOCK BAKELIKE PINK)
# ..        ...                                                ...
# 126  0.030534  (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG RED...
# 127  0.042051  (JUMBO BAG PINK POLKADOT, JUMBO BAG RED RETROS...
# 128  0.035194  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...
# 129  0.037390  (JUMBO STORAGE BAG SUKI, JUMBO BAG RED RETROSPOT)
# 130  0.032516  (LUNCH BAG RED RETROSPOT, LUNCH BAG  BLACK SKU...
#
# [131 rows x 2 columns]

# %%
# generate association rules
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1)
rules
# Out:
#                             antecedents  ... zhangs_metric
# 0          (ALARM CLOCK BAKELIKE GREEN)  ...      0.967905
# 1           (ALARM CLOCK BAKELIKE RED )  ...      0.970852
# 2      (PINK REGENCY TEACUP AND SAUCER)  ...      0.975789
# 3     (GREEN REGENCY TEACUP AND SAUCER)  ...      0.988499
# 4     (GREEN REGENCY TEACUP AND SAUCER)  ...      0.980766
# 5    (ROSES REGENCY TEACUP AND SAUCER )  ...      0.982040
# 6      (JUMBO  BAG BAROQUE BLACK WHITE)  ...      0.877013
# 7             (JUMBO BAG RED RETROSPOT)  ...      0.930903
# 8             (JUMBO BAG PINK POLKADOT)  ...      0.902774
# 9             (JUMBO BAG RED RETROSPOT)  ...      0.944810
# 10  (JUMBO SHOPPER VINTAGE RED PAISLEY)  ...      0.874018
# 11            (JUMBO BAG RED RETROSPOT)  ...      0.916073
# 12             (JUMBO STORAGE BAG SUKI)  ...      0.885537
# 13            (JUMBO BAG RED RETROSPOT)  ...      0.928305
# 14            (LUNCH BAG RED RETROSPOT)  ...      0.919160
# 15            (LUNCH BAG  BLACK SKULL.)  ...      0.909891
#
# [16 rows x 10 columns]

# %%
basket.shape
# Out:
# (18668, 4188)

# %%
basket.head()
# Out:
# Description  20713  ...  wrongly sold sets
# InvoiceNo           ...
# 536365         0.0  ...                0.0
# 536366         0.0  ...                0.0
# 536367         0.0  ...                0.0
# 536368         0.0  ...                0.0
# 536369         0.0  ...                0.0
#
# [5 rows x 4188 columns]

# %%
# filter rules by a minimum lift and confidence
filtered_rules = rules[(rules['lift'] >= 3.0) & (rules['confidence'] >= .5)]

# %%
# print the association rules
print(filtered_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
#                             antecedents  ...       lift
# 0          (ALARM CLOCK BAKELIKE GREEN)  ...  12.900874
# 1           (ALARM CLOCK BAKELIKE RED )  ...  12.900874
# 2      (PINK REGENCY TEACUP AND SAUCER)  ...  16.404818
# 3     (GREEN REGENCY TEACUP AND SAUCER)  ...  16.404818
# 4     (GREEN REGENCY TEACUP AND SAUCER)  ...  14.640537
# 5    (ROSES REGENCY TEACUP AND SAUCER )  ...  14.640537
# 6      (JUMBO  BAG BAROQUE BLACK WHITE)  ...   6.033613
# 8             (JUMBO BAG PINK POLKADOT)  ...   6.524245
# 10  (JUMBO SHOPPER VINTAGE RED PAISLEY)  ...   5.585724
# 12             (JUMBO STORAGE BAG SUKI)  ...   5.950055
#
# [10 rows x 5 columns]
