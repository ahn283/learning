# %% [markdown]
# # Install and Import Library

# %%
import yfinance as yf   # pip install yfinance

# %% [markdown]
# # Historical stock prices

# %%
# import library
import yfinance as yf
import pandas as pd 
from datetime import datetime

# create ticker instance
aapl = yf.Ticker('AAPL')

# get today date and convert it to a string formtted YYYY-MM-DD
end_date = datetime.now().strftime('%Y-%m-%d')
aapl_stock_price = aapl.history(start='2020-01-01', end=end_date)
pd.DataFrame(aapl_stock_price)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-01-02 00:00:00-05:00   71.878871   72.936773   71.624105   72.876114
# 2020-01-03 00:00:00-05:00   72.099672   72.931916   71.941959   72.167610
# 2020-01-06 00:00:00-05:00   71.284393   72.781460   71.032048   72.742638
# 2020-01-07 00:00:00-05:00   72.752363   73.009558   72.179742   72.400543
# 2020-01-08 00:00:00-05:00   72.102106   73.868505   72.102106   73.565208
# ...                               ...         ...         ...         ...
# 2024-09-09 00:00:00-04:00  220.820007  221.270004  216.710007  220.910004
# 2024-09-10 00:00:00-04:00  218.919998  221.479996  216.729996  220.110001
# 2024-09-11 00:00:00-04:00  221.460007  223.089996  217.889999  222.660004
# 2024-09-12 00:00:00-04:00  222.500000  223.550003  219.820007  222.770004
# 2024-09-13 00:00:00-04:00  223.580002  224.039993  221.910004  222.500000
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
# getting the max 1 minute data.
aapl_min = appl.history(period='max', end=end_date, interval='1m')
pd.DataFrame(aapl_min)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-09-09 09:30:00-04:00  220.899994  221.000000  219.899994  220.220001
# 2024-09-09 09:31:00-04:00  220.255005  220.960007  220.255005  220.949997
# 2024-09-09 09:32:00-04:00  220.949997  220.949997  220.470001  220.485703
# 2024-09-09 09:33:00-04:00  220.479996  221.270004  220.479996  220.899994
# 2024-09-09 09:34:00-04:00  220.850006  220.889999  220.429993  220.600006
# ...                               ...         ...         ...         ...
# 2024-09-13 15:55:00-04:00  222.470001  222.669998  222.330002  222.490005
# 2024-09-13 15:56:00-04:00  222.520004  222.559998  222.399994  222.464996
# 2024-09-13 15:57:00-04:00  222.460007  222.509995  222.339996  222.470001
# 2024-09-13 15:58:00-04:00  222.470001  222.520004  222.419998  222.460007
# 2024-09-13 15:59:00-04:00  222.460007  222.470001  222.389999  222.460007
#
#                             Volume  Dividends  Stock Splits
# ...

# %%
# multiple assets
companies = ['AMZN', 'GOOG', 'WNT', 'TSLA', 'META']
tickers = yf.Tickers(companies)
ticker_prices = tickers.history(period='max', end=end_date, interval='1m')
pd.DataFrame(ticker_prices)
# Out:
# [*********************100%***********************]  5 of 5 completed
#
# 1 Failed download:
# ['WNT']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1m 2024-09-09 00:00:00-04:00 -> 2024-09-16)')
# Price                     Adj Close       Close                          \
# Ticker                          WNT        AMZN        GOOG        META
# 2024-09-09 13:30:00+00:00       NaN  173.589996  153.728195  505.739990
# 2024-09-09 13:31:00+00:00       NaN  173.839996  153.979996  507.010010
# 2024-09-09 13:32:00+00:00       NaN  174.425003  154.300003  507.720001
# 2024-09-09 13:33:00+00:00       NaN  175.110504  154.309998  508.184998
# 2024-09-09 13:34:00+00:00       NaN  174.949997  154.440002  507.795013
# ...                             ...         ...         ...         ...
# 2024-09-13 19:55:00+00:00       NaN  186.696594  158.404999  524.960022
# 2024-09-13 19:56:00+00:00       NaN  186.520004  158.360001  524.570007
# ...

# %%
# transform multi-level index into a single-index set of columns
ticker_prices.stack(level=1).rename_axis(['Date', 'Ticker']).reset_index(level=1)
# Out:
# Price                     Ticker  Adj Close       Close  Dividends  \
# Date
# 2024-09-09 13:30:00+00:00   AMZN        NaN  173.589996        0.0
# 2024-09-09 13:30:00+00:00   GOOG        NaN  153.728195        0.2
# 2024-09-09 13:30:00+00:00   META        NaN  505.739990        0.0
# 2024-09-09 13:30:00+00:00   TSLA        NaN  214.330093        0.0
# 2024-09-09 13:31:00+00:00   AMZN        NaN  173.839996        0.0
# ...                          ...        ...         ...        ...
# 2024-09-13 19:58:00+00:00   TSLA        NaN  230.229996        0.0
# 2024-09-13 19:59:00+00:00   AMZN        NaN  186.470001        0.0
# 2024-09-13 19:59:00+00:00   GOOG        NaN  158.330002        0.0
# 2024-09-13 19:59:00+00:00   META        NaN  524.520020        0.0
# 2024-09-13 19:59:00+00:00   TSLA        NaN  230.270004        0.0
#
# Price                            High         Low        Open  Stock Splits  \
# Date
# ...

# %% [markdown]
# # Fetch Fundamental Data

# %%
import yfinance as yf  

# createa ticker instance of 'Tesla'
tsla = yf.Ticker('TSLA')

# call the functions
tsla_actions = tsla.get_actions()
tsla_analyst = tsla.get_analyst_price_targets()
tsla_balance = tsla.get_balance_sheet()
tsla_calendar = tsla.get_calendar()
tsla_cf = tsla.get_cash_flow()
tsla_info = tsla.get_info()
tsla_inst_holders = tsla.get_institutional_holders()
tsla_news = tsla.get_news()
tsla_recommendation = tsla.get_recommendations()
tsla_sustainability = tsla.get_sustainability()

# print the results
print(tsla_actions)
print('-'*20)
print(tsla_analyst)
print('-'*20)
print(tsla_balance)
print('-'*20)
print(tsla_calendar)
print('-'*20)
print(tsla_cf)
print('-'*20)
print(tsla_info)
print('-'*20)
print(tsla_inst_holders)
print('-'*20)
print(tsla_news)
print('-'*20)
print(tsla_recommendation)
print('-'*20)
print(tsla_sustainability)
print('-'*20)
# Out:
#                            Dividends  Stock Splits
# Date
# 2020-08-31 00:00:00-04:00        0.0           5.0
# 2022-08-25 00:00:00-04:00        0.0           3.0
# --------------------
# {'current': 230.29, 'low': 24.86, 'high': 310.0, 'mean': 211.31, 'median': 222.5}
# --------------------
#                                                2023-12-31     2022-12-31  \
# TreasurySharesNumber                                  0.0            NaN
# OrdinarySharesNumber                         3185000000.0   3164000000.0
# ShareIssued                                  3185000000.0   3164000000.0
# NetDebt                                               NaN            NaN
# TotalDebt                                    9573000000.0   5748000000.0
# ...                                                   ...            ...
# CashCashEquivalentsAndShortTermInvestments  29094000000.0  22185000000.0
# OtherShortTermInvestments                   12696000000.0   5932000000.0
# ...

# %% [markdown]
# # Fetch Options Chain Data

# %%
# import library
import yfinance as yf

# create a ticker of Tesla
tsla = yf.Ticker('TSLA')

# fetch options chain data
tsla_options = tsla.option_chain()

# access both the calls and puts and store then in their respective variables
tsla_puts = tsla_options.puts
tsla_calls = tsla_options.calls

# %%
tsla_calls
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice  bid  \
# 0    TSLA240920C00005000 2024-09-13 15:04:06+00:00     5.0     225.18  0.0
# 1    TSLA240920C00010000 2024-08-26 17:38:55+00:00    10.0     202.77  0.0
# 2    TSLA240920C00015000 2024-09-11 19:43:58+00:00    15.0     211.45  0.0
# 3    TSLA240920C00020000 2024-09-04 15:27:55+00:00    20.0     200.27  0.0
# 4    TSLA240920C00025000 2024-09-04 18:19:03+00:00    25.0     196.15  0.0
# ..                   ...                       ...     ...        ...  ...
# 114  TSLA240920C00520000 2024-09-13 14:30:18+00:00   520.0       0.01  0.0
# 115  TSLA240920C00530000 2024-09-05 14:12:46+00:00   530.0       0.01  0.0
# 116  TSLA240920C00540000 2024-09-05 19:10:29+00:00   540.0       0.01  0.0
# 117  TSLA240920C00550000 2024-09-13 13:49:42+00:00   550.0       0.01  0.0
# 118  TSLA240920C00560000 2024-09-13 13:30:10+00:00   560.0       0.01  0.0
#
# ...

# %% [markdown]
# # Tips and tricks

# %% [markdown]
# ## Plotting a Candlestick Chart using yfinance and finplot

# %%
# import libraries
import yfinance as yf   # pip install yfinance
import finplot as fplt  # pip install finplot

# create a ticker of Tesla
tsla = yf.Ticker('TSLA')

# retrieve 1 year worth of daily data of Tesla
df = tsla.history(interval='1d', period='1y')

# plot the OHLC candle chart
fplt.candlestick_ochl(df[['Open', 'Close', 'High', 'Low']])
fplt.show()
